# %% [markdown]
# <a href="https://colab.research.google.com/github/kebab03/2side/blob/main/newpdf2image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdf2jpg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 25.4 MB/s eta 0:00:00
# ...
#   Created wheel for img2pdf: filename=img2pdf-0.4.4-py3-none-any.whl size=44880 sha256=43020477795d20ab86e9cfef76b9f1e05e247876021dd73ee6b9c90c0722b244
#   Stored in directory: /root/.cache/pip/wheels/9e/70/4e/193fef3784ff9e9e7c8a3a54e9b580441a4137f3fa4bbb76cd
# Successfully built img2pdf
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ...

# %%
from pdf2jpg import pdf2jpg
inputpath = r"my_pdf_file.pdf"
outputpath = r""
result = pdf2jpg.convert_pdf2jpg(inputpath,outputpath, pages="ALL")

# %%
# !pip install easyocr --no-deps # Colab already has all dependencies
# !pip install python-bidi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 69.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.6.2 requires ninja, which is not installed.
# easyocr 1.6.2 requires pyclipper, which is not installed.
# easyocr 1.6.2 requires opencv-python-headless<=4.5.4.60, but you have opencv-python-headless 4.7.0.72 which is incompatible.
# ...

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("my_pdf_file.pdf_dir/0_my_pdf_file.pdf.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3035x2149>

# %%
import easyocr
reader = easyocr.Reader(['it','en'])
bounds = reader.readtext("my_pdf_file.pdf_dir/0_my_pdf_file.pdf.jpg")
print(bounds)
# Out:
# WARNING:easyocr.easyocr:CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# ...

# %%
bounds
# Out:
# [([[2128, 88], [2743, 88], [2743, 126], [2128, 126]],
#   'TESSERA EUROPEA DI ASSICURAZIONE MALATTIA',
#   0.48656627275414227),
#  ([[1981, 445], [2134, 445], [2134, 484], [1981, 484]],
#   'IZEKOR',
#   0.9999254415486767),
#  ([[1985, 508], [2116, 508], [2116, 553], [1985, 553]],
#   'DORIS',
#   0.9989160973771909),
#  ([[2674, 500], [2909, 500], [2909, 548], [2674, 548]],
#   '15/03/1973',
#   0.9999880499184239),
#  ([[2028, 558], [2066, 558], [2066, 572], [2028, 572]],
#   'Wiu',
#   0.035161820245542964),
#  ([[2154, 556], [2217, 556], [2217, 574], [2154, 574]],
#   'n',
#   0.2549821942888606),
#  ([[1982, 570], [2373, 570], [2373, 619], [1982, 619]],
#   'ZKRDRS73C55Z335F',
#   0.7501399660857926),
#  ([[2408, 570], [2741, 570], [2741, 612], [2408, 612]],
#   'SSN-MIN SALUTE',
#   0.9871053220834016),
#  ([[2766, 568], [2905, 568], [2905, 610], [2766, 610]],
#   '500001',
#   0.9989402474184526),
#  ([[1982, 636], [2453, 636], [2453, 685], [1982, 685]],
# ...
